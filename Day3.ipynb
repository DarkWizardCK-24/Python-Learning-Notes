# %%
lst = [80, 96, 79, 30, 4]
print(lst[3])
print(lst[1:3])
lst.append(58)
print(lst)
lst.pop(4)
print(lst)
lst.insert(1,44)
lst.sort()
print(lst)
# Out:
# 30
# [96, 79]
# [80, 96, 79, 30, 4, 58]
# [80, 96, 79, 30, 58]
# [30, 44, 58, 79, 80, 96]

# %%
set = {1,3,4,2,1,5,6,5,4,6}
print(set)

for x in set:
  print(x)

set.discard(4)
print(set)
set.update([8,7])
print(set)
# Out:
# {1, 2, 3, 4, 5, 6}
# 1
# 2
# 3
# 4
# 5
# 6
# {1, 2, 3, 5, 6}
# {1, 2, 3, 5, 6, 7, 8}

# %%
zoo =['lion', 'tiger', 'wolf', 'rabbit', 'elephant']
print(zoo)
zoo.pop(3)
print(zoo)
zoo.append("rabbit")
print(zoo)
zoo.pop(0)
print(zoo)
print(zoo[:3])
# Out:
# ['lion', 'tiger', 'wolf', 'rabbit', 'elephant']
# ['lion', 'tiger', 'wolf', 'elephant']
# ['lion', 'tiger', 'wolf', 'elephant', 'rabbit']
# ['tiger', 'wolf', 'elephant', 'rabbit']
# ['tiger', 'wolf', 'elephant']
